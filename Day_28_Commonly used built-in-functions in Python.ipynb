# %% [markdown]
# # Commonly used built-in-functions in Python

# %% [markdown]
# # 1. print(): Outputs text or variables to the Console

# %%
print('data science')
# Out:
# data science

# %% [markdown]
# # 2. len(): Returns the length of an object

# %%
my_list = [1,2,3,4,5]
length = len(my_list)

# %%
length
# Out:
# 5

# %% [markdown]
# # 3. input(): Reads input from the user

# %%
user_input = input('Enter something: ')
# Out:
# Enter something:  Study Mart

# %%
user_input
# Out:
# 'Study Mart'

# %% [markdown]
# # 4. type(): Returns the type of an object

# %%
x = 5

# %%
type_of_x = type(x)

# %%
type_of_x
# Out:
# int

# %%
#or
type(x)
# Out:
# int

# %% [markdown]
# # 5.int(), float(), str(): Convert values to integers, floats, strings

# %%
num_str = '42'

# %%
num_int = int(num_str)

# %%
num_int
# Out:
# 42

# %%
num_float = float(num_int)

# %%
num_float
# Out:
# 42.0

# %%
#or
int(num_str)
# Out:
# 42

# %%
float(num_str)
# Out:
# 42.0

# %%
num_str2 = str (num_int)

# %%
num_str2
# Out:
# '42'

# %% [markdown]
# # 6. range(): Generates a sequence of numbers

# %%
numbers = list(range(1,6))           #create a list [1,2,3,4,5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # 7. sum(): Returns the sum of all elements in an iterable

# %%
my_list = [1,2,3,4,5]

# %%
sum(my_list)
# Out:
# 15

# %%
#or
total = sum(my_list)

# %%
total
# Out:
# 15

# %% [markdown]
# # 8. max(),min(): Returns the Maximum and Minimum value from an iterable

# %%
numbers = [3,1,5,8,9,12]

# %%
max_value = max(numbers)
min_value = min(numbers)

# %%
max_value
# Out:
# 12

# %%
min_value
# Out:
# 1

# %%
n = {1,2}
max(n)
# Out:
# 2

# %% [markdown]
# # 9. abs(): Returns the absolute value of a number

# %%
absolute_value = abs(-10)
absolute_value
# Out:
# 10

# %% [markdown]
# # 10. round(): Rounds a floating point number to a specified number of a decimals

# %%
rounded_number = round(3.14159, 2)         # rounds to 2 decimal places
rounded_number
# Out:
# 3.14

# %% [markdown]
# # 11. sorted(): Returns a new sorted list from the elements of an iterable

# %%
numbers = [1,4,5,9,6,3]
sorted_numbers = sorted(numbers)
sorted_numbers
# Out:
# [1, 3, 4, 5, 6, 9]

# %% [markdown]
# # 12. any(),all(): Returns True if any or all elements in an iterable are true

# %%
bool_list = [True, False, True, True, False]
any_true = any(bool_list)
all_true = all(bool_list)

# %%
any_true
# Out:
# True

# %%
all_true
# Out:
# False

# %% [markdown]
# # 13. str.join(): Joins the elements of an iterable with a string as a separable

# %%
my_list = ['apple','orange','banana']
joined_str = ' ; '.join(my_list)
joined_str
# Out:
# 'apple ; orange ; banana'

# %% [markdown]
# # 14. str.upper(),str.lower(): Converts a string to uppercase or lowercase

# %%
my_string = 'Hello, world!'
lower_case = my_string.lower()
upper_case = my_string.upper()

# %%
lower_case
# Out:
# 'hello, world!'

# %%
upper_case
# Out:
# 'HELLO, WORLD!'

# %% [markdown]
# # 15. list(), tuple(): Converts an iterable to a list or a tuple

# %%
my_tuple = (2,3,4)
tuple_to_list = list(my_tuple)
tuple_to_list
# Out:
# [2, 3, 4]

# %%
list_to_tuple = tuple(tuple_to_list)

# %%
list_to_tuple
# Out:
# (2, 3, 4)

# %% [markdown]
# # 16. dict(): Creates a dictionary

# %%
my_dict = dict(name ='John', age = 25)
my_dict
# Out:
# {'name': 'John', 'age': 25}

# %%
my_dict.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_dict.values()
# Out:
# dict_values(['John', 25])

# %% [markdown]
# # 17. set(): Creates a set

# %%
my_set = set([2,3,4,5])
my_set
# Out:
# {2, 3, 4, 5}

# %% [markdown]
# # 18. enumerate(): Returns tuples with index and corresponding elements

# %%
my_list = ['a','b','c']
for index, value in enumerate(my_list):
    print(index, value)
# Out:
# 0 a
# 1 b
# 2 c

# %% [markdown]
# # 19. zip(): combines two or more iterables element wise

# %%
names = ['nusrat','jahan','mimi']
ages = [22, 23, 24]
zipped_data = zip(names, ages)

# %%
zipped_data

# %%
type(zipped_data)
# Out:
# zip

# %% [markdown]
# # 20. reversed(): Returns a reversed iterator of a sequence

# %%
my_list = [1,2,3]
reversed_list = list(reversed(my_list))

# %%
reversed_list
# Out:
# [3, 2, 1]

# %% [markdown]
# # 21. sum() (with start argument): Returns the sum of an iterable with an optional starting value

# %%
numbers = [2,3,4]
total = sum(numbers, 100)           #sum starting from 100

# %%
total
# Out:
# 109

# %% [markdown]
# # 22. abs() (for complex numbers): Returns the magnitude of a complex numbers

# %%
from IPython.display import Image
Image (filename = r'C:\Users\49176\Pictures\Screenshots\Abs.png')

# %%
complex_num = 3 + 4j
magnitude = abs(complex_num)

# %%
magnitude
# Out:
# 5.0

# %% [markdown]
# # 23. slice(): Creates a slice object that can be used to slice a sequences like lists and strings

# %%
my_lists = [1, 2, 3, 4, 5]
my_slice = slice(1, 4)
sliced_list = my_lists[my_slice]
sliced_list
# Out:
# [2, 3, 4]

# %% [markdown]
# # 24. chr(), ord() (extended usage): Handling unicode characters and code points

# %%
euro_symbol = chr(8364)          #returns '€'
code_point = ord('€')            #returns 8364

# %%
euro_symbol
# Out:
# '€'

# %%
code_point
# Out:
# 8364

# %%
char = chr(65)
print (char)         #output 'A'
# Out:
# A

# %%
code_point = ord('A')
print(code_point)           #output:65
# Out:
# 65
