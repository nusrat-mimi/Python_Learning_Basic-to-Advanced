# %%
import zipfile as zp
zipp = zp.ZipFile ('Zipped.zip', 'w')                     #w stands for write

zipp.write (r'C:\Users\49176\Downloads\Python Learning_Study mart\For Zip practice\CV.docx')
zipp.write (r'C:\Users\49176\Downloads\Python Learning_Study mart\For Zip practice\List comprehension.png')
zipp.write (r'C:\Users\49176\Downloads\Python Learning_Study mart\For Zip practice\Full sign.jpg')

# %% [markdown]
# # Unzip

# %%
with zp.ZipFile ('Zipped.zip', 'r') as file:               # r stands for read
    file.extractall('Temp Unzip')
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with zp.ZipFile ('Zipped.zip', 'r') as file:               # r stands for read
#       2     file.extractall('Temp Unzip')
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1385, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1383 try:
#    1384     if mode == 'r':
# -> 1385         self._RealGetContents()
#    1386     elif mode in ('w', 'x'):
#    1387         # set the modified flag so central directory gets written
#    1388         # even if no files are added to the archive
#    1389         self._didModify = True
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1452, in ZipFile._RealGetContents(self)
#    1450     raise BadZipFile("File is not a zip file")
#    1451 if not endrec:
# ...
