# %% [markdown]
# # *List methods*
# #organize list

# %%
#list
list1 = ['ai','ds','cs',150,20,True,[3,4],(1,2)]

# %%
list1                     #list access #I changed later list1 due to learn different items cause showing change version
# Out:
# ['Germany',
#  '1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100],
#  {1, 2, 3, 4},
#  10,
#  100]

# %%
#indexing

# %%
list1 [0]
# Out:
# 'ai'

# %%
list1 [-1]
# Out:
# (1, 2)

# %%
list1 [-1] [0]
# Out:
# 1

# %%
list1 [-1] [-2]
# Out:
# 1

# %% [markdown]
# # copy()

# %%
list2 = list1

# %%
list2
# Out:
# ['ai', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list3 = list1.copy()

# %%
list3
# Out:
# ['ai', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list1 [0] = '1000'

# %%
list1
# Out:
# ['1000', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list2
# Out:
# ['1000', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list3
# Out:
# ['ai', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list3 [0] = 'data'

# %%
list3
# Out:
# ['data', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %%
list1
# Out:
# ['1000', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2)]

# %% [markdown]
# # append()
# #add value, full tuple or full list

# %%
list1.append(28)

# %%
list1
# Out:
# ['1000', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2), 28]

# %%
l1 = [10, 100]

# %%
list1.append(l1)

# %%
list1
# Out:
# ['1000', 'ds', 'cs', 150, 20, True, [3, 4], (1, 2), 28, [10, 100]]

# %%
list1 [-1]
# Out:
# [10, 100]

# %%
list1.append({1,2,3,4})

# %%
list1
# Out:
# ['1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100],
#  {1, 2, 3, 4}]

# %% [markdown]
# # extend()
# #add value separately

# %%
list1.extend(l1)

# %%
list1
# Out:
# ['1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100],
#  {1, 2, 3, 4},
#  10,
#  100]

# %%
list1 [-1]
# Out:
# 100

# %% [markdown]
# # insert
# #add value in any index

# %%
list1.insert(0, 'Freie')

# %%
list1
# Out:
# ['Freie',
#  '1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100],
#  {1, 2, 3, 4},
#  10,
#  100]

# %%
list1 [0] ='Germany'            #index change

# %%
list1
# Out:
# ['Germany',
#  '1000',
#  'ds',
#  'cs',
#  150,
#  20,
#  True,
#  [3, 4],
#  (1, 2),
#  28,
#  [10, 100],
#  {1, 2, 3, 4},
#  10,
#  100]

# %% [markdown]
# # index()

# %%
list1.index({1,2,3,4})
# Out:
# 11

# %%
list1.index('Germany')
# Out:
# 0

# %% [markdown]
# # count()
# #check how many times the value present in the list

# %%
list1.count(150)
# Out:
# 1

# %%
list1.count({1,2,3,4})
# Out:
# 1

# %% [markdown]
# # sort()
# #organize in a ascending way

# %%
ls2 = [10, 2, 6, 7, 9, 100]

# %%
ls2.sort()

# %%
ls2
# Out:
# [2, 6, 7, 9, 10, 100]

# %% [markdown]
# # reverse()

# %%
ls2.reverse()

# %%
ls2
# Out:
# [100, 10, 9, 7, 6, 2]

# %% [markdown]
# # remove()
# #remove item from the begining

# %%
ls2.remove(100)

# %%
ls2
# Out:
# [10, 9, 7, 6, 2]

# %% [markdown]
# # pop()
# #remove item by indexing

# %%
ls2.pop(-2)
# Out:
# 6

# %%
ls2
# Out:
# [10, 9, 7, 2]

# %%
del ls2 [0]    #del is a key word also remove item by indexing

# %%
ls2
# Out:
# [9, 7, 2]

# %% [markdown]
# # clear()
# #remove all items

# %%
ls2.clear()

# %%
ls2
# Out:
# []

# %%
type (ls2)
# Out:
# list
