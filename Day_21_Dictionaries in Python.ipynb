# %% [markdown]
# # Dictionaries
# #dict{}
# #ordered, changeable, no duplicate allows

# %%
from IPython.display import Image
Image (filename = r'C:\Users\49176\Pictures\Screenshots\Data collection types.png')

# %%
dic = {
    'name' : 'Mimi', 
    'varsity' : 'CU'                                #key/id = name, varsity
}                                                   #values = Mimi, CU

# %%
dic
# Out:
# {'name': 'Mimi', 'varsity': 'CU'}

# %%
dic.keys()                               # to check keys
# Out:
# dict_keys(['name', 'varsity'])

# %%
type (dic)
# Out:
# dict

# %%
dic.values()                             # to check values
# Out:
# dict_values(['Mimi', 'CU'])

# %%
dic2 = dic.copy()                           #to copy

# %%
dic2
# Out:
# {'name': 'Mimi', 'varsity': 'CU'}

# %%
dic ['varsity'] = 'Freie'                   #if i want to change values using key

# %%
dic
# Out:
# {'name': 'Mimi', 'varsity': 'Freie'}

# %%
dic ['dept'] = 'Pharmacy'                   #add new key and values

# %%
dic
# Out:
# {'name': 'Mimi', 'varsity': 'Freie', 'dept': 'Pharmacy'}

# %%
dic.update({'dept': 'Medicine'})                        #to update values

# %%
dic
# Out:
# {'name': 'Mimi', 'varsity': 'Freie', 'dept': 'Medicine'}

# %%
dic.popitem()                                        #to remove last item
# Out:
# ('dept', 'Medicine')

# %%
dic
# Out:
# {'name': 'Mimi', 'varsity': 'Freie'}

# %%
dic.pop('varsity')                                  #to remove specific item
# Out:
# 'Freie'

# %%
dic
# Out:
# {'name': 'Mimi'}

# %%
dic ['dept']= 'Pharmacy'

# %%
dic
# Out:
# {'name': 'Mimi', 'dept': 'Pharmacy'}

# %%
del dic['name']                                #also can use del func to remove item

# %%
dic
# Out:
# {'dept': 'Pharmacy'}

# %%
dic ['dept2'] = 'Medicine'

# %%
dic
# Out:
# {'dept': 'Pharmacy', 'dept2': 'Medicine'}

# %%
#print all items
for x in dic:
    print(x)                                 #by default x takes key
# Out:
# dept
# dept2

# %%
for x in dic:
    print(dic [x])                            # to see the values in loop
# Out:
# Pharmacy
# Medicine

# %%
d2 = list(dic.keys())                         #dic to list_take keys and values separately

# %%
d2
# Out:
# ['dept', 'dept2']

# %%
d3 = list(dic.values())

# %%
d3
# Out:
# ['Pharmacy', 'Medicine']

# %%
#dic from user input
n = int(input())
d = {}

for i in range (n):
    keys = input()
    values = input()
    d[keys] = values

print(d)
# Out:
#  3
#  name
#  mimi
#  dept
#  pharmacy
#  dept2
#  medicine
# {'name': 'mimi', 'dept': 'pharmacy', 'dept2': 'medicine'}

# %%
d
# Out:
# {'name': 'mimi', 'dept': 'pharmacy', 'dept2': 'medicine'}
