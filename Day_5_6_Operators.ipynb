# %% [markdown]
# # *Arithmatic Operators*

# %%
#Assigning the variables
x = 15
y = 4
z = 3

# %%
x+y
# Out:
# 19

# %%
x-y
# Out:
# 11

# %%
x/y
# Out:
# 3.75

# %%
x*y
# Out:
# 60

# %%
2 * 2
# Out:
# 4

# %%
2 ** 2
# Out:
# 4

# %%
15 * 15 * 15 * 15
# Out:
# 50625

# %%
x ** y #x=15 to the power 4, as y=4 called Exponentiation
# Out:
# 50625

# %%
x/y
# Out:
# 3.75

# %%
x//y #floor division
# Out:
# 3

# %%
import math

# %%
math.floor(x/y) #floor division check
# Out:
# 3

# %%
math.ceil(x/y)
# Out:
# 4

# %%
x%y #modulus
# Out:
# 3

# %% [markdown]
# # **Python Identity Operators**

# %%
x = 10
y = 10

# %%
x is y
# Out:
# True

# %%
x == y #comparison operator
# Out:
# True

# %%
x = 10017
y = x
z = 10017

# %%
x is y
# Out:
# True

# %%
x is z
# Out:
# False

# %%
id(x)
# Out:
# 2376908368400

# %%
id(y)
# Out:
# 2376908368400

# %%
id(z)
# Out:
# 2376908368848

# %%
x == z
# Out:
# True

# %%
x is not z
# Out:
# True

# %% [markdown]
# # *Membership operator*

# %%
list1 = [1,2,3,4,5,6,7]
1 in list1
# Out:
# True

# %%
10 in list1
# Out:
# False

# %%
10 not in list1
# Out:
# True

# %%
set1 = {1,2,3,4,5}

# %%
1 in set1
# Out:
# True

# %%
string = 'Learning Python'
'python' in string
# Out:
# False

# %%
'Python' in string
# Out:
# True

# %% [markdown]
# # *Bitwise operator* work based on binary

# %%
x = 1010 #10 , 1011, 1100, 1101, 1110, 1111
y = 0101 #5 
x | y = 1111
x & y = 0000

# %%
x = 10
y = 5
x | y
# Out:
# 15

# %%
x & y
# Out:
# 0

# %%
# *Comparison Operator* True/False

# %%
10 == 10
# Out:
# True

# %%
10 > 10
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
# *logical operator* True/ False.

# %%
10 < 4 and 10 >3
# Out:
# False

# %%
10 > 9 and 10 > 3
# Out:
# True

# %%
10 < 4 or 10 >3
# Out:
# True

# %%
not (10 < 4 or 10 >3)
# Out:
# False

# %%
#*Assignment Operator

# %%
x = 10
x += 4 # x = x+4
