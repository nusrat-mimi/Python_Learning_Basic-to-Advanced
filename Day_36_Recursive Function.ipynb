# %% [markdown]
# #Recursion

# %%
# 5! = 5*4*3*2*1 = 120

def facto(x):
    if x==0:
        return 1
    return x* facto(x-1)

# %%
facto(5)
# Out:
# 120

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000
