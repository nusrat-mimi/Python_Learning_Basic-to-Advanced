# %% [markdown]
# # More about return

# %%
def user_input():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())

    return x1, y1

# %%
user_input()
# Out:
#  1
#  2
#  3
#  4
# (1, 3)

# %%
def user_input():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())

    return x1, y1, x2, y2

# %%
user_input()
# Out:
#  1
#  2
#  3
#  4
# (1, 3, 2, 4)

# %%
def user_input():
    x1 = int(input())
    x2 = int(input())
    y1 = int(input())
    y2 = int(input())

    return (x1, y1), (x2, y2)

# %%
user_input()
# Out:
#  1
#  2
#  3
#  4
# ((1, 3), (2, 4))

# %%
r1, r2 = user_input()
# Out:
#  1
#  2
#  3
#  4

# %%
r1
# Out:
# (1, 3)

# %%
r2
# Out:
# (2, 4)

# %%
r1,_ = user_input()        #have to take underscore for skip
# Out:
#  1
#  2
#  3
#  4

# %%
r1
# Out:
# (1, 3)

# %%
r1 = user_input()
# Out:
#  1
#  2
#  3
#  4

# %%
r1
# Out:
# ((1, 3), (2, 4))

# %%
def sq_and_cube(x):
    sq = x**2
    cube = x**3
    return sq, cube
sq_and_cube(3)
# Out:
# (9, 27)

# %%
# A function within a function

# %%
def mulp():
    x = int(input('x = '))
    y = int(input('y = '))
    result = x*y
    print(result)

# %%
mulp()
# Out:
# x =  10
# y =  20
# 200

# %%
def mulp1():
    x = int(input('x = '))
    y = int(input('y = '))
    result = x*y
    print('result  ', result)
    return result

def mulp2():
    total1 = mulp1()
    z = int(input('z = '))
    total2 = total1 * z
    print('Fonal result = ', total2)

# %%
mulp2()
# Out:
# x =  2
# y =  5
# result   10
# z =  6
# Fonal result =  60
